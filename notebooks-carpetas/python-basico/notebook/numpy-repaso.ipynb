# %%
import pandas as pd
import numpy as np

# %%
ruta = "/Users/angelgarciachanga/repositorios/publico/angel-notebooks/notebooks-carpetas/python_basico/data/input/winequality-red.csv"

df = pd.read_csv(ruta, sep = ';')

# %%
#Convertir el dataframe en un ndarray (elemento de numpy)
data = df.to_numpy()

# %%
#Es un array de 2 dimensiones
data.ndim
# Out:
# 2

# %% [markdown]
# #Numpy solo sabe de posiciones en dimensiones (no de filas y columnas)

# %%
#dimensión 0 → 1599 elementos
#dimensión 1 → 12 elementos
data.shape
# Out:
# (1599, 12)

# %%
#Accerder al primer elemento de la dimesión 0 y a todos los elementos de la dimensión 1
data[0,:]
# Out:
# array([ 7.4   ,  0.7   ,  0.    ,  1.9   ,  0.076 , 11.    , 34.    ,
#         0.9978,  3.51  ,  0.56  ,  9.4   ,  5.    ])

# %%
#“Dame el elemento en la posición 0 de la dimensión 0 y en la posición 3 de la dimensión 1”
data[0,3]
# Out:
# np.float64(1.9)

# %%
data[:,3]
# Out:
# array([1.9, 2.6, 2.3, ..., 2.3, 2. , 3.6], shape=(1599,))
